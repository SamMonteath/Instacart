# %% [markdown]
# Notes on difficulty importing .pkl or .csv
#
# Importing from Google Drive
#
# Initial checks
#
# Merging dataframes – Difficulties
#
# Working with sample only
#
# Merging dataframes

# %%
## -- Loading Libraries --
import pandas as pd
import numpy as np
import os

# %% [markdown]
# **Notes on difficulty importing .pkl or .csv**

# %% [markdown]
# Tried importing as a .pkl and as a .csv, but neither uploaded the whole df
#
# E.g. as a .csv
# What I exported had the shape: (32434489, 11)
# But what I re-imported has FAR fewer rows: (185556, 12)
#
# Co-pilot suggested uploading / downloading to Drive, so trying that

# %% [markdown]
# **Importing from Google Drive**

# %%
#Importing google drive#

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#Importing the df from drive#

df_ords_prods = pd.read_pickle('/content/drive/MyDrive/ords_prods_comb.pkl')

# %% [markdown]
# **Initial checks**

# %%
#checking what has imported#

df_ords_prods
# Out:
#           order_id  user_id eval_set  order_number  order_dow  \
# 0          2539329        1    prior             1          2
# 1          2539329        1    prior             1          2
# 2          2539329        1    prior             1          2
# 3          2539329        1    prior             1          2
# 4          2539329        1    prior             1          2
# ...            ...      ...      ...           ...        ...
# 32434484   2977660   206209    prior            13          1
# 32434485   2977660   206209    prior            13          1
# 32434486   2977660   206209    prior            13          1
# 32434487   2977660   206209    prior            13          1
# 32434488   2977660   206209    prior            13          1
#
#           order_hour_of_day  days_since_prior_order  product_id  \
# 0                         8                     NaN         196
# 1                         8                     NaN       14084
# ...

# %% [markdown]
# THIS WORKS - CAN CONTINUE!

# %% [markdown]
# **Merging dataframes - Difficulties**

# %% [markdown]
# Having imported both dfs, I tried to merge the full dfs together - but a straight merge, an inner or left join only all instantly crashed
#
# # merge onto prods #
#
# Needed to drop the _merge column from df_ords_prods
#
# Tried an inner join only
#
# df_merged = df_prods.merge(df_ords_prods.drop(columns=['_merge']), on='product_id', how='inner', indicator=True)
#
# Tried a left join
# df_merged = df_prods.merge(df_ords_prods.drop(columns=['_merge']), on='product_id', how='left', indicator=True)

# %% [markdown]
# #this was a suggestion from Co Pilot#
#
# df_ords_prods_reduced = df_ords_prods[df_ords_prods['product_id'].isin(df_prods['product_id'])]
#
# But this in fact INCREASED the memory usage from 2.4 to 2.7 GB

# %% [markdown]
# **Working with sample only**

# %%
##Another Co-pilot suggestion - work with a sample only ##
#Should mean we're only working with a sample - not crashing the system#

df_ords_prods_sample = df_ords_prods.sample(frac=0.1)

# %%
df_ords_prods_sample.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3243449 entries, 23642705 to 12869431
# Data columns (total 11 columns):
#  #   Column                  Dtype
# ---  ------                  -----
#  0   order_id                int64
#  1   user_id                 int64
#  2   eval_set                object
#  3   order_number            int64
#  4   order_dow               int64
#  5   order_hour_of_day       int64
#  6   days_since_prior_order  float64
#  7   product_id              int64
#  8   add_to_cart_order       int64
#  9   reordered               int64
#  10  _merge                  category
# dtypes: category(1), float64(1), int64(8), object(1)
# memory usage: 275.3+ MB

# %%
#Importing the products df - from prepared data - this is a LOT smaller

df_prods = pd.read_csv(r'/content/products_checked.csv', index_col = False)

# %%
df_prods
# Out:
#        Unnamed: 0  product_id  \
# 0               0           1
# 1               1           2
# 2               2           3
# 3               3           4
# 4               4           5
# ...           ...         ...
# 49667       49688       49684
# 49668       49689       49685
# 49669       49690       49686
# 49670       49691       49687
# 49671       49692       49688
#
#                                             product_name  aisle_id  \
# 0                             Chocolate Sandwich Cookies        61
# 1                                       All-Seasons Salt       104
# 2                   Robust Golden Unsweetened Oolong Tea        94
# 3      Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4                              Green Chile Anytime Sauce         5
# ...                                                  ...       ...
# 49667          Vodka, Triple Distilled, Twist of Vanilla       124
# ...

# %% [markdown]
# These look more usable, so will attempt a merge

# %% [markdown]
# **Merging dataframes**

# %%
df_merged = df_prods.merge(df_ords_prods_sample.drop(columns=['_merge']), on = 'product_id', indicator = True)

# %%
df_merged.shape
# Out:
# (3240395, 16)

# %%
df_merged
# Out:
#          Unnamed: 0  product_id                product_name  aisle_id  \
# 0                 0           1  Chocolate Sandwich Cookies        61
# 1                 0           1  Chocolate Sandwich Cookies        61
# 2                 0           1  Chocolate Sandwich Cookies        61
# 3                 0           1  Chocolate Sandwich Cookies        61
# 4                 0           1  Chocolate Sandwich Cookies        61
# ...             ...         ...                         ...       ...
# 3240390       49692       49688      Fresh Foaming Cleanser        73
# 3240391       49692       49688      Fresh Foaming Cleanser        73
# 3240392       49692       49688      Fresh Foaming Cleanser        73
# 3240393       49692       49688      Fresh Foaming Cleanser        73
# 3240394       49692       49688      Fresh Foaming Cleanser        73
#
#          department_id  prices  order_id  user_id eval_set  order_number  \
# ...

# %%
df_merged['_merge'].value_counts()
# Out:
# _merge
# both          3240395
# left_only           0
# right_only          0
# Name: count, dtype: int64

# %% [markdown]
# Going to be honest, I've merged something, but I'm not sure I can visualise what it is I have done.
#
# This feels a bit more like an exercise in not making colab crash rather then mastering merging

# %%
#Export to drive#

df_merged.to_pickle('/content/drive/MyDrive/ord_prod_id_comb.pkl')

# %%
from google.colab import drive
drive.mount('/content/drive')
