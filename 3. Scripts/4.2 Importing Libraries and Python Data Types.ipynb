# %% [markdown]
# #01. Importing Libraries

# %% [markdown]
# # Import libraries

# %%
import pandas as pd

# %%
import numpy as np

# %%
import os

# %% [markdown]
# #Exercises

# %%
x = 10

# %%
y = 20

# %%
z = 5

# %%
x * x
# Out:
# 100

# %%
y * z
# Out:
# 100

# %%
((x*y)/z)*(z/(y/x))
# Out:
# 100.0

# %%
a = 1.7436

# %%
b = 465.987

# %%
a*b
# Out:
# 812.4949332000001

# %%
d = "Please "

# %%
c = "help!"

# %%
d + c
# Out:
# 'Please help!'

# %%
e = " cried the man in ditress"

# %%
f = "I'm stuck with this maths problem! "

# %%
d + c + e
# Out:
# 'Please help! cried the man in ditress'

# %%
f + d + c
# Out:
# "I'm stuck with this maths problem! Please help!"

# %%
(d+c)*100
# Out:
# 'Please help!Please help!Please help!Please help!Please help!Please help!Please help!Please help!Please help!Please help!Please help!Please help!Please help!Please help!Please help!Please help!Please help!Please help!Please help!Please help!Please help!Please help!Please help!Please help!Please help!Please help!Please help!Please help!Please help!Please help!Please help!Please help!Please help!Please help!Please help!Please help!Please help!Please help!Please help!Please help!Please help!Please help!Please help!Please help!Please help!Please help!Please help!Please help!Please help!Please help!Please help!Please help!Please help!Please help!Please help!Please help!Please help!Please help!Please help!Please help!Please help!Please help!Please help!Please help!Please help!Please help!Please help!Please help!Please help!Please help!Please help!Please help!Please help!Please help!Please help!Please help!Please help!Please help!Please help!Please help!Please help!Please help!Please help!P
# ...

# %% [markdown]
# # Integers

# %%
x = 2

# %%
print(x)
# Out:
# 2

# %%
type(x)
# Out:
# int

# %% [markdown]
# # Float

# %%
y = 5.678

# %%
type(y)
# Out:
# float

# %% [markdown]
# #Strings

# %%
z = 'Brazil'

# %%
type(z)
# Out:
# str

# %%
type(mania)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-14-2298294286.py in <cell line: 0>()
# ----> 1 type(mania)
#
# NameError: name 'mania' is not defined

# %%
type('mania')
# Out:
# str

# %% [markdown]
# #Boolean

# %%
type(True)
# Out:
# bool

# %% [markdown]
# #Calculation

# %%
x + 4
# Out:
# 6

# %%
x / y
# Out:
# 0.3522367030644593

# %%
a = "Hello, "

# %%
b = "Marley"

# %%
a + b
# Out:
# 'Hello, Marley'

# %%
n = "potato"

# %%
n * 12
# Out:
# 'potatopotatopotatopotatopotatopotatopotatopotatopotatopotatopotatopotato'

# %%
x == y
# Out:
# False

# %%
type(x == y)
# Out:
# bool
