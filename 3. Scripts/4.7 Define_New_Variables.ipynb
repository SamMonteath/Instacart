# %% [markdown]
# # In this script, I find the values in a column. I categorise those values as new variable, and then create a new column for that new variable.
# # E.g. busiest times of day
#
# Defining and running a function
#
# Importing libraries and drive
#
# Import df and initial checks
#
# Using a subset (first million rows)
#
# Creating a new function - a price flag - using if/elif/else
#
# Applying function - to a new 'price_range' column
#
# Finding maximum value in a column
#
# Creating the same function - a price flag - using loc()
#
# Apply price flag using loc()
#
# Counting all values in a column
#
# Using if/elif/else to create a busy day flag – a NEW VARIABLE
#
# Populating new column with created variable
#
# TASK
#
# Value counts for a column
#
# Amending our newly created 'busiest_day' column
#
# Changing column name
#
# Putting new result into column
#
# Creating a busiest times column
#
# Find busiest times with .value_counts on a column
#
# Create new variable 'result_hours' - using if/elif/else based on busiest times
#
# Create new column and attach variable

# %% [markdown]
# **Defining and running a function**

# %%
#Define function

def add_num (x,y):
  sum = x + y
  return sum

# %%
#Run fnction
add_num (9,11)
# Out:
# 20

# %% [markdown]
# **Importing libraries and drive**

# %%
## -- Loading Libraries --
import pandas as pd
import numpy as np
import os

# %%
#Importing google drive#

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# **Import df and initial checks**

# %%
#Importing the df from drive#

df_ord_prod_id_comb = pd.read_pickle('/content/drive/MyDrive/ord_prod_id_comb.pkl')

# %%
#Quick check

df_ord_prod_id_comb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3240395 entries, 0 to 3240394
# Data columns (total 16 columns):
#  #   Column                  Dtype
# ---  ------                  -----
#  0   Unnamed: 0              int64
#  1   product_id              int64
#  2   product_name            object
#  3   aisle_id                int64
#  4   department_id           int64
#  5   prices                  float64
#  6   order_id                int64
#  7   user_id                 int64
#  8   eval_set                object
#  9   order_number            int64
#  10  order_dow               int64
#  11  order_hour_of_day       int64
#  12  days_since_prior_order  float64
#  13  add_to_cart_order       int64
#  14  reordered               int64
#  15  _merge                  category
# dtypes: category(1), float64(2), int64(11), object(2)
# memory usage: 373.9+ MB

# %% [markdown]
# **Using a subset (first million rows)**

# %%
#Using a subset of first million rows

df = df_ord_prod_id_comb[:1000000]

# %%
#shows reduced memory usage

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000000 entries, 0 to 999999
# Data columns (total 16 columns):
#  #   Column                  Non-Null Count    Dtype
# ---  ------                  --------------    -----
#  0   Unnamed: 0              1000000 non-null  int64
#  1   product_id              1000000 non-null  int64
#  2   product_name            1000000 non-null  object
#  3   aisle_id                1000000 non-null  int64
#  4   department_id           1000000 non-null  int64
#  5   prices                  1000000 non-null  float64
#  6   order_id                1000000 non-null  int64
#  7   user_id                 1000000 non-null  int64
#  8   eval_set                1000000 non-null  object
#  9   order_number            1000000 non-null  int64
#  10  order_dow               1000000 non-null  int64
#  11  order_hour_of_day       1000000 non-null  int64
#  12  days_since_prior_order  936078 non-null   float64
# ...

# %%
df.head()
# Out:
#    Unnamed: 0  product_id                product_name  aisle_id  \
# 0           0           1  Chocolate Sandwich Cookies        61
# 1           0           1  Chocolate Sandwich Cookies        61
# 2           0           1  Chocolate Sandwich Cookies        61
# 3           0           1  Chocolate Sandwich Cookies        61
# 4           0           1  Chocolate Sandwich Cookies        61
#
#    department_id  prices  order_id  user_id eval_set  order_number  order_dow  \
# 0             19     5.8   2907475    96682    prior            23          4
# 1             19     5.8   3038506    39081    prior            16          2
# 2             19     5.8   3185203    95847    prior            49          1
# 3             19     5.8   1830804    14910    prior            56          4
# 4             19     5.8   1701441      777    prior            16          1
#
#    order_hour_of_day  days_since_prior_order  add_to_cart_order  reordered  \
# ...

# %%
df.shape
# Out:
# (1000000, 16)

# %% [markdown]
# **Creating a new function - a price flag - using if/elif/else**

# %%
#Defining our function

def price_label(row):

  if row['prices'] <= 5:
    return 'Low-range product'
  elif (row['prices'] > 5) and (row['prices'] <= 15):
    return 'Mid-range product'
  elif row['prices'] > 15:
    return 'High range'
  else: return 'Not enough data'

# %% [markdown]
# **Applying function - to a new'price_range' column**

# %%
# Applying our function

df['price_range'] = df.apply(price_label, axis=1)
# Out:
# /tmp/ipython-input-12-1426942562.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price_range'] = df.apply(price_label, axis=1)

# %%
#checking that we have addeded a column, which we have

df.shape
# Out:
# (1000000, 17)

# %%
#Examining the values in the date set
##(i get a different answer to the exercise - beacuse I created a different merged file)

df['price_range'].value_counts(dropna=False)
# Out:
# price_range
# Mid-range product    657304
# Low-range product    324537
# High range            18159
# Name: count, dtype: int64

# %% [markdown]
# **Finding maximum value in a column**

# %%
#Checking the max price
df['prices'].max()
# Out:
# 25.0

# %% [markdown]
# **Creating the same function - a price flag - using loc()**

# %%
# Using loc() for the same if/then process - loc() is faster

# %%
df.loc[df['prices'] > 15, 'price_range_loc'] = 'High-range product'
# Out:
# /tmp/ipython-input-16-1169838859.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[df['prices'] > 15, 'price_range_loc'] = 'High-range product'

# %%
df.loc[(df['prices'] <= 15) & (df['prices'] > 5), 'price_range_loc'] = 'Mid-range product'

# %%
df.loc[df['prices'] <= 5, 'price_range_loc'] = 'Low-range product'

# %%
df['price_range_loc'].value_counts(dropna=False)
# Out:
# price_range_loc
# Mid-range product     657304
# Low-range product     324537
# High-range product     18159
# Name: count, dtype: int64

# %% [markdown]
# Produces same result as previously
#
# Can we now do it on whole dataframe?

# %% [markdown]
# **Apply price flag using loc()**

# %%
df_ord_prod_id_comb.loc[df['prices'] > 15, 'price_range_loc'] = 'High-range product'

# %%
df_ord_prod_id_comb.loc[(df_ord_prod_id_comb['prices'] <= 15) & (df_ord_prod_id_comb['prices'] > 5), 'price_range_loc'] = 'Mid-range product'

# %%
df_ord_prod_id_comb.loc[df_ord_prod_id_comb['prices'] <= 5, 'price_range_loc'] = 'Low-range product'

# %%
df_ord_prod_id_comb['price_range_loc'].value_counts(dropna=False)
# Out:
# price_range_loc
# Mid-range product     2185912
# Low-range product     1012816
# High-range product      41667
# Name: count, dtype: int64

# %% [markdown]
# **Can** do it on whole data frame and categorise them all with our new variable

# %% [markdown]
# **Counting all values in a column**

# %%
df_ord_prod_id_comb['order_dow'].value_counts(dropna=False)
# Out:
# order_dow
# 0    620384
# 1    566687
# 6    448670
# 2    421069
# 5    420480
# 3    385235
# 4    377870
# Name: count, dtype: int64

# %% [markdown]
# **Using if/elif/else to create a busy day flag - a NEW VARIABLE**

# %%
#Defining our new variable - result - which is about busiest days

result = []

for value in df_ord_prod_id_comb['order_dow']:
  if value == 0:
    result.append("Busiest day")
  elif value == 4:
    result.append("Least busy")
  else:
    result.append("Regularly busy")

# %%
#quick look

result
# Out:
# ['Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest day',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest day',
#  'Regularly busy',
#  'Busiest day',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest day',
#  'Busiest day',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
# ...

# %% [markdown]
# **Populating new column with created variable**

# %%
#Populating a new column with our new varibale

df_ord_prod_id_comb['busiest_day'] = result

# %%
#Checking frequency

df_ord_prod_id_comb['busiest_day'].value_counts(dropna=False)
# Out:
# busiest_day
# Regularly busy    2242141
# Busiest day        620384
# Least busy         377870
# Name: count, dtype: int64

# %%
df_ord_prod_id_comb['order_dow'].value_counts(dropna=False)
# Out:
# order_dow
# 0    620384
# 1    566687
# 6    448670
# 2    421069
# 5    420480
# 3    385235
# 4    377870
# Name: count, dtype: int64

# %%
#checking these totals add up - without doing it manually

df_ord_prod_id_comb['busiest_day'].value_counts(dropna=False).sum()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'busiest_day'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-55-3178802300.py in <cell line: 0>()
# ...

# %%
df_ord_prod_id_comb['order_dow'].value_counts(dropna=False).sum()
# Out:
# np.int64(3240395)

# %% [markdown]
# numbers match - all good!

# %% [markdown]
# # **TASK**

# %% [markdown]
# **Value counts for a column**

# %%
#Reminding myself of busiest days

df_ord_prod_id_comb['order_dow'].value_counts(dropna=False)
# Out:
# order_dow
# 0    620384
# 1    566687
# 6    448670
# 2    421069
# 5    420480
# 3    385235
# 4    377870
# Name: count, dtype: int64

# %% [markdown]
# **Amending our newly created 'busiest_day' column**

# %%
#Changing the result to look at 2 busiest and 2 least busy days

result = []

for value in df_ord_prod_id_comb['order_dow']:
  if value in [0, 1]:
    result.append("Busiest days")
  elif value in [3, 4]:
    result.append("Least busy days")
  else:
    result.append("Regularly busy days")

# %% [markdown]
# **Changing column name**

# %%
#Rename 'busiest day' to 'busiest days'

df_ord_prod_id_comb = df_ord_prod_id_comb.rename(columns={'busiest_day': 'busiest_days'})

# %% [markdown]
# **Putting new result into column**

# %%
# Populating the 'busiest days' column with our result

df_ord_prod_id_comb['busiest_days'] = result

# %%
#seeing how that has changed the column

df_ord_prod_id_comb['busiest_days'].value_counts(dropna=False)
# Out:
# busiest_days
# Regularly busy days    1290219
# Busiest days           1187071
# Least busy days         763105
# Name: count, dtype: int64

# %%
#Checking still get the same overall number of rows

df_ord_prod_id_comb['busiest_days'].value_counts(dropna=False).sum()
# Out:
# np.int64(3240395)

# %% [markdown]
# Same number again, so all good

# %% [markdown]
# **Creating a busiest times column**

# %% [markdown]
# **Find busiest times with .value_counts on a column**

# %%
#What are the busiest times?

df_ord_prod_id_comb['order_hour_of_day'].value_counts(dropna=False)
# Out:
# order_hour_of_day
# 10    277030
# 11    274547
# 14    268683
# 15    266334
# 13    266030
# 12    261716
# 16    252909
# 9     245232
# 17    208456
# 8     171599
# 18    163364
# 19    125820
# 20     97954
# 7      88932
# 21     79749
# 22     63433
# 23     39894
# 6      28913
# 0      21810
# 1      11693
# 5       8853
# 2       6914
# 4       5362
# 3       5168
# Name: count, dtype: int64

# %% [markdown]
# **Create new variable 'result_hours' - using if/elif/else based on busiest times**

# %%
#Defining new variable 'result_hours'

result_hours = []

for value in df_ord_prod_id_comb['order_hour_of_day']:
  if value in[10,11,14]:
    result_hours.append("Busiest time")
  elif value in [3,4,2]:
    result_hours.append("Least busy time")
  else:
    result_hours.append("Regularly busy time")

# %%
# quick check

result_hours
# Out:
# ['Busiest time',
#  'Regularly busy time',
#  'Regularly busy time',
#  'Regularly busy time',
#  'Regularly busy time',
#  'Regularly busy time',
#  'Busiest time',
#  'Regularly busy time',
#  'Busiest time',
#  'Regularly busy time',
#  'Regularly busy time',
#  'Regularly busy time',
#  'Regularly busy time',
#  'Busiest time',
#  'Busiest time',
#  'Regularly busy time',
#  'Regularly busy time',
#  'Regularly busy time',
#  'Regularly busy time',
#  'Regularly busy time',
#  'Regularly busy time',
#  'Regularly busy time',
#  'Regularly busy time',
#  'Regularly busy time',
#  'Busiest time',
#  'Regularly busy time',
#  'Least busy time',
#  'Regularly busy time',
#  'Regularly busy time',
#  'Busiest time',
#  'Busiest time',
#  'Regularly busy time',
#  'Regularly busy time',
#  'Regularly busy time',
#  'Busiest time',
#  'Regularly busy time',
#  'Regularly busy time',
#  'Busiest time',
#  'Busiest time',
#  'Regularly busy time',
#  'Regularly busy time',
# ...

# %% [markdown]
# **Create new column and attach variable**

# %%
#creating a new column and attaching our new variable

df_ord_prod_id_comb['busiest_time'] = result_hours

# %%
#Looking at the column

df_ord_prod_id_comb['busiest_time'].value_counts(dropna=False)
# Out:
# busiest_time
# Regularly busy time    2402691
# Busiest time            820260
# Least busy time          17444
# Name: count, dtype: int64

# %%
##Checking we get the same number of rows, which we do!

df_ord_prod_id_comb['busiest_time'].value_counts(dropna=False).sum()
# Out:
# np.int64(3240395)

# %%
#Export to drive#

df_ord_prod_id_comb.to_pickle('/content/drive/MyDrive/merged_frequency.pkl')
