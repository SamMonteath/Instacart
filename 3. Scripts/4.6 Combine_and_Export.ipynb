# %% [markdown]
# Importing and Initial Checks
#
# Merging two dataframes
#
# Export as pickle file
#
# Export to Google Drive

# %%
## -- Loading Libraries --
import pandas as pd
import numpy as np
import os

# %% [markdown]
# **Importing and Initial Checks**

# %%
#Importing the new df
df_ords_prior = pd.read_csv(r'/content/orders_products_prior.csv', index_col = False)

# %%
df_ords_prior.head()
# Out:
#    order_id  product_id  add_to_cart_order  reordered
# 0         2       33120                  1          1
# 1         2       28985                  2          1
# 2         2        9327                  3          0
# 3         2       45918                  4          1
# 4         2       30035                  5          0

# %%
df_ords_prior.shape
# Out:
# (32434489, 4)

# %%
#Importing the original orders df df
df_ords = pd.read_csv(r'/content/orders.csv', index_col = False)

# %%
df_ords.head()
# Out:
#    order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1    prior             1          2                  8
# 1   2398795        1    prior             2          3                  7
# 2    473747        1    prior             3          3                 12
# 3   2254736        1    prior             4          4                  7
# 4    431534        1    prior             5          4                 15
#
#    days_since_prior_order
# 0                     NaN
# 1                    15.0
# 2                    21.0
# 3                    29.0
# 4                    28.0

# %%
df_ords.shape
# Out:
# (3421083, 7)

# %% [markdown]
# **Merging two dataframes**

# %%
df_merged_large = df_ords.merge(df_ords_prior, on = 'order_id', indicator = True)

# %%
df_merged_large.head()
# Out:
#    order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1    prior             1          2                  8
# 1   2539329        1    prior             1          2                  8
# 2   2539329        1    prior             1          2                  8
# 3   2539329        1    prior             1          2                  8
# 4   2539329        1    prior             1          2                  8
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered _merge
# 0                     NaN         196                  1          0   both
# 1                     NaN       14084                  2          0   both
# 2                     NaN       12427                  3          0   both
# 3                     NaN       26088                  4          0   both
# 4                     NaN       26405                  5          0   both

# %%
df_merged_large.shape
# Out:
# (32434489, 11)

# %%
df_merged_large['_merge'].value_counts()
# Out:
# _merge
# both          32434489
# left_only            0
# right_only           0
# Name: count, dtype: int64

# %% [markdown]
# **Export as pickle file**

# %% [markdown]
# df_merged_large.to_pickle(os.path.join(r'/content/', 'orders_products_combined.pkl'))
#
# that produces a pkl file that is 2.4GB - going to compare to a csv

# %% [markdown]
# Export our merged df as a csv file
#
# df_merged_large.to_csv(os.path.join(r'/content/', 'orders_products_combined.csv'))
#
# csv is 1.7 GB - may use that if pkl is unusable

# %% [markdown]
# I've found both very hard to reload
#
# For now - going to try to save to Drive instead

# %% [markdown]
# **Export to Google drive**

# %%
#Import drive##

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#Export to drive#

df_merged_large.to_pickle('/content/drive/MyDrive/ords_prods_comb.pkl')

# %% [markdown]
# Appears to be successful
