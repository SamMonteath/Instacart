# %% [markdown]
# PREPARATION
#
# Dropping a column
#
# Reviwing a column
#
# Renaming a column
#
# Changing data type
#
# Transposing data
#
# Adding an index column
#
# Creating a data dictionary
#
# Creating a subset of the data frame
#
# Indexing
#
# TASK
#
# Changing data type
#
# Renaming columns
#
# Find count of all values in a column
#
# Using a data dictionary
#
# Creating a subset
#
# Subset of multiple items
#
# Find information relating to one value

# %%
## -- Loading Libraries --
import pandas as pd
import numpy as np
import os

# %%
## --- first upload to folders, then run this to upload to this notebook ----

df_ords = pd.read_csv(r'/content/orders.csv', index_col = False)
df_prods = pd.read_csv(r'/content/products.csv', index_col = False)

# %% [markdown]
# Dropping a column

# %%
##excluding eval-set column
#have established it has limited values and adds nothing to the analysis

df_ords.drop(columns = ['eval_set'])
# Out:
#         order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0        2539329        1             1          2                  8
# 1        2398795        1             2          3                  7
# 2         473747        1             3          3                 12
# 3        2254736        1             4          4                  7
# 4         431534        1             5          4                 15
# ...          ...      ...           ...        ...                ...
# 138589   2924019     8338            38          0                 20
# 138590    202460     8338            39          0                 10
# 138591   3081992     8338            40          2                 15
# 138592   3201742     8338            41          0                 11
# 138593   2340331     8338            42          1                 18
#
#         days_since_prior_order
# 0                          NaN
# 1                         15.0
# ...

# %%
#Showing everthing going on in a column
df_ords['eval_set'].value_counts(dropna = False)
# Out:
# eval_set
# prior    130257
# train      5299
# test       3038
# Name: count, dtype: int64

# %% [markdown]
# Reviewing a column

# %%
## All the different values in days_since_prior_order

df_ords['days_since_prior_order'].value_counts(dropna = False)
# Out:
# days_since_prior_order
# 30.0    14712
# 7.0     12996
# 6.0      9593
# 3.0      8985
# 4.0      8964
# 5.0      8616
# NaN      8338
# 2.0      8202
# 8.0      7250
# 1.0      5933
# 9.0      4829
# 14.0     4016
# 10.0     3855
# 11.0     3269
# 13.0     3231
# 12.0     3156
# 0.0      2758
# 15.0     2694
# 16.0     1923
# 21.0     1873
# 17.0     1628
# 20.0     1570
# 18.0     1523
# 19.0     1352
# 22.0     1331
# 28.0     1010
# 23.0      919
# 27.0      900
# 26.0      823
# 24.0      815
# 25.0      798
# 29.0      732
# Name: count, dtype: int64

# %% [markdown]
# Renaming a column

# %%
##renaming a column

df_ords.rename(columns = {'order_dow' : 'orderd_day_of_week'}, inplace = True)

# %%
df_ords.rename(columns = {'orderd_day_of_week' : 'orderds_day_of_week'}, inplace = True)

# %%
df_ords
# Out:
#         order_id  user_id eval_set  order_number  orderds_day_of_week  \
# 0        2539329        1    prior             1                    2
# 1        2398795        1    prior             2                    3
# 2         473747        1    prior             3                    3
# 3        2254736        1    prior             4                    4
# 4         431534        1    prior             5                    4
# ...          ...      ...      ...           ...                  ...
# 138589   2924019     8338    prior            38                    0
# 138590    202460     8338    prior            39                    0
# 138591   3081992     8338    prior            40                    2
# 138592   3201742     8338    prior            41                    0
# 138593   2340331     8338    prior            42                    1
#
#         order_hour_of_day  days_since_prior_order
# 0                       8                     NaN
# ...

# %%
## Eventually spelling it right!

df_ords.rename(columns = {'orderds_day_of_week' : 'orders_day_of_week'}, inplace = True)

# %%
df_ords
# Out:
#         order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0        2539329        1    prior             1                   2
# 1        2398795        1    prior             2                   3
# 2         473747        1    prior             3                   3
# 3        2254736        1    prior             4                   4
# 4         431534        1    prior             5                   4
# ...          ...      ...      ...           ...                 ...
# 138589   2924019     8338    prior            38                   0
# 138590    202460     8338    prior            39                   0
# 138591   3081992     8338    prior            40                   2
# 138592   3201742     8338    prior            41                   0
# 138593   2340331     8338    prior            42                   1
#
#         order_hour_of_day  days_since_prior_order
# 0                       8                     NaN
# ...

# %%
df_ords.describe()
# Out:
#            order_id        user_id   order_number  orders_day_of_week  \
# count  1.385940e+05  138594.000000  138594.000000       138594.000000
# mean   1.710601e+06    4221.438093      17.280221            2.795871
# std    9.889246e+05    2401.868257      17.934762            2.045520
# min    8.000000e+00       1.000000       1.000000            0.000000
# 25%    8.551818e+05    2157.000000       5.000000            1.000000
# 50%    1.710074e+06    4286.500000      11.000000            3.000000
# 75%    2.566776e+06    6292.000000      24.000000            5.000000
# max    3.421068e+06    8338.000000     100.000000            6.000000
#
#        order_hour_of_day  days_since_prior_order
# count      138594.000000           130256.000000
# mean           13.451138               11.039883
# std             4.206474                9.178217
# min             0.000000                0.000000
# 25%            10.000000                4.000000
# ...

# %% [markdown]
# Changing data type

# %%
## Don't want to perform any calculations on Order ID, it's just a descriptor - so change type to String

df_ords['order_id'] = df_ords['order_id'].astype('str')

# %%
## Which means it doesn't no appear when we look at the numeric columns

df_ords.describe()
# Out:
#              user_id   order_number  orders_day_of_week  order_hour_of_day  \
# count  138594.000000  138594.000000       138594.000000      138594.000000
# mean     4221.438093      17.280221            2.795871          13.451138
# std      2401.868257      17.934762            2.045520           4.206474
# min         1.000000       1.000000            0.000000           0.000000
# 25%      2157.000000       5.000000            1.000000          10.000000
# 50%      4286.500000      11.000000            3.000000          13.000000
# 75%      6292.000000      24.000000            5.000000          16.000000
# max      8338.000000     100.000000            6.000000          23.000000
#
#        days_since_prior_order
# count           130256.000000
# mean                11.039883
# std                  9.178217
# min                  0.000000
# 25%                  4.000000
# 50%                  7.000000
# 75%                 15.000000
# max                 30.000000

# %%
##Checkig what type it is

# ='O' = object = string

df_ords['order_id'].dtype
# Out:
# dtype('O')

# %% [markdown]
# Transposing data

# %%
##Upload departments

df_dep = pd.read_csv(r'/content/departments.csv', index_col = False)

# %%
## View the datafrane
df_dep.head()
# Out:
#   department_id       1      2       3        4        5              6  \
# 0    department  frozen  other  bakery  produce  alcohol  international
#
#            7     8                9  ...            12      13         14  \
# 0  beverages  pets  dry goods pasta  ...  meat seafood  pantry  breakfast
#
#              15          16         17      18      19    20       21
# 0  canned goods  dairy eggs  household  babies  snacks  deli  missing
#
# [1 rows x 22 columns]

# %%
#Transposing data - VISUALLY

df_dep.T
# Out:
#                              0
# department_id       department
# 1                       frozen
# 2                        other
# 3                       bakery
# 4                      produce
# 5                      alcohol
# 6                international
# 7                    beverages
# 8                         pets
# 9              dry goods pasta
# 10                        bulk
# 11               personal care
# 12                meat seafood
# 13                      pantry
# 14                   breakfast
# 15                canned goods
# 16                  dairy eggs
# 17                   household
# 18                      babies
# 19                      snacks
# 20                        deli
# 21                     missing

# %%
#Transposing data - Permanently

df_dep_t = df_dep.T

# %%
#Checking done properly

df_dep_t
# Out:
#                              0
# department_id       department
# 1                       frozen
# 2                        other
# 3                       bakery
# 4                      produce
# 5                      alcohol
# 6                international
# 7                    beverages
# 8                         pets
# 9              dry goods pasta
# 10                        bulk
# 11               personal care
# 12                meat seafood
# 13                      pantry
# 14                   breakfast
# 15                canned goods
# 16                  dairy eggs
# 17                   household
# 18                      babies
# 19                      snacks
# 20                        deli
# 21                     missing

# %% [markdown]
# Adding an index column

# %%
## Adding an index column to the data - so that can identify rows by their index number
df_dep_t.reset_index()
# Out:
#             index                0
# 0   department_id       department
# 1               1           frozen
# 2               2            other
# 3               3           bakery
# 4               4          produce
# 5               5          alcohol
# 6               6    international
# 7               7        beverages
# 8               8             pets
# 9               9  dry goods pasta
# 10             10             bulk
# 11             11    personal care
# 12             12     meat seafood
# 13             13           pantry
# 14             14        breakfast
# 15             15     canned goods
# 16             16       dairy eggs
# 17             17        household
# 18             18           babies
# 19             19           snacks
# 20             20             deli
# 21             21          missing

# %%
## Need to get rid of this weird first row
## creating an object 'new_header' that conatins the first row, row 0

new_header = df_dep_t.iloc[0]

# %%
##Checking what we've got
new_header
# Out:
# 0    department
# Name: department_id, dtype: object

# %%
## Creating a new dataframe from only the rows after the first row

df_dep_t_new = df_dep_t[1:]

# %%
##Checking that

df_dep_t_new
# Out:
#                   0
# 1            frozen
# 2             other
# 3            bakery
# 4           produce
# 5           alcohol
# 6     international
# 7         beverages
# 8              pets
# 9   dry goods pasta
# 10             bulk
# 11    personal care
# 12     meat seafood
# 13           pantry
# 14        breakfast
# 15     canned goods
# 16       dairy eggs
# 17        household
# 18           babies
# 19           snacks
# 20             deli
# 21          missing

# %%
## Instruction to create a new header from the current data frame

df_dep_t_new.columns = new_header

# %%
##Checking that

df_dep_t_new
# Out:
# department_id       department
# 1                       frozen
# 2                        other
# 3                       bakery
# 4                      produce
# 5                      alcohol
# 6                international
# 7                    beverages
# 8                         pets
# 9              dry goods pasta
# 10                        bulk
# 11               personal care
# 12                meat seafood
# 13                      pantry
# 14                   breakfast
# 15                canned goods
# 16                  dairy eggs
# 17                   household
# 18                      babies
# 19                      snacks
# 20                        deli
# 21                     missing

# %% [markdown]
# Creating a data dictionary

# %%
## Turning df_dep_t_new into a data dictionary

data_dict = df_dep_t_new.to_dict('index')

# %%
##Checking what that creates
data_dict
# Out:
# {'1': {'department': 'frozen'},
#  '2': {'department': 'other'},
#  '3': {'department': 'bakery'},
#  '4': {'department': 'produce'},
#  '5': {'department': 'alcohol'},
#  '6': {'department': 'international'},
#  '7': {'department': 'beverages'},
#  '8': {'department': 'pets'},
#  '9': {'department': 'dry goods pasta'},
#  '10': {'department': 'bulk'},
#  '11': {'department': 'personal care'},
#  '12': {'department': 'meat seafood'},
#  '13': {'department': 'pantry'},
#  '14': {'department': 'breakfast'},
#  '15': {'department': 'canned goods'},
#  '16': {'department': 'dairy eggs'},
#  '17': {'department': 'household'},
#  '18': {'department': 'babies'},
#  '19': {'department': 'snacks'},
#  '20': {'department': 'deli'},
#  '21': {'department': 'missing'}}

# %%
df_prods.head()
# Out:
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id  prices
# 0             19     5.8
# 1             13     9.3
# 2              7     4.5
# 3              1    10.5
# 4             13     4.3

# %%
#What does department 19 mean?

print(data_dict.get('19'))
# Out:
# {'department': 'snacks'}

# %% [markdown]
# Creating a subset of the datafram

# %%
#Subset

## just looking at snacks - departmentid = 19 - in df_prods

df_snacks =  df_prods[df_prods['department_id']==19]

# %%
df_snacks
# Out:
#        product_id                                   product_name  aisle_id  \
# 0               1                     Chocolate Sandwich Cookies        61
# 15             16                  Mint Chocolate Flavored Syrup       103
# 24             25        Salted Caramel Lean Protein & Fiber Bar         3
# 31             32                  Nacho Cheese White Bean Chips       107
# 40             41    Organic Sourdough Einkorn Crackers Rosemary        78
# ...           ...                                            ...       ...
# 49666       49662                   Bacon Cheddar Pretzel Pieces       107
# 49669       49665  Super Dark Coconut Ash & Banana Chocolate Bar        45
# 49670       49666                  Ginger Snaps Snacking Cookies        61
# 49675       49671                           Milk Chocolate Drops        45
# 49683       49679                        Famous Chocolate Wafers        61
#
#        department_id  prices
# 0                 19     5.8
# ...

# %% [markdown]
# Indexing

# %%
#Indexing

## Loking just at an ['element'} with an object - here is df_prods

## This tells you for all rows in department_id, which is dept 19

df_prods['department_id']==19
# Out:
# 0         True
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 49688    False
# 49689    False
# 49690    False
# 49691    False
# 49692    False
# Name: department_id, Length: 49693, dtype: bool

# %%
## When put WITHIN df-prods like this, it gives the whole df, but just those that are Dept 19

df_prods[df_prods['department_id']==19]
# Out:
#        product_id                                   product_name  aisle_id  \
# 0               1                     Chocolate Sandwich Cookies        61
# 15             16                  Mint Chocolate Flavored Syrup       103
# 24             25        Salted Caramel Lean Protein & Fiber Bar         3
# 31             32                  Nacho Cheese White Bean Chips       107
# 40             41    Organic Sourdough Einkorn Crackers Rosemary        78
# ...           ...                                            ...       ...
# 49666       49662                   Bacon Cheddar Pretzel Pieces       107
# 49669       49665  Super Dark Coconut Ash & Banana Chocolate Bar        45
# 49670       49666                  Ginger Snaps Snacking Cookies        61
# 49675       49671                           Milk Chocolate Drops        45
# 49683       49679                        Famous Chocolate Wafers        61
#
#        department_id  prices
# 0                 19     5.8
# ...

# %%
#Set the above as a new df

df_snacks = df_prods[df_prods['department_id']==19]

# %%
df_snacks.head()
# Out:
#     product_id                                 product_name  aisle_id  \
# 0            1                   Chocolate Sandwich Cookies        61
# 15          16                Mint Chocolate Flavored Syrup       103
# 24          25      Salted Caramel Lean Protein & Fiber Bar         3
# 31          32                Nacho Cheese White Bean Chips       107
# 40          41  Organic Sourdough Einkorn Crackers Rosemary        78
#
#     department_id  prices
# 0              19     5.8
# 15             19     5.2
# 24             19     1.9
# 31             19     4.9
# 40             19     6.5

# %%
## Can do the same thing this way

## loc looks for a coulumn name

df_snacks_2 = df_prods.loc[df_prods['department_id'] == 19]

# %%
df_snacks_2.head()
# Out:
#     product_id                                 product_name  aisle_id  \
# 0            1                   Chocolate Sandwich Cookies        61
# 15          16                Mint Chocolate Flavored Syrup       103
# 24          25      Salted Caramel Lean Protein & Fiber Bar         3
# 31          32                Nacho Cheese White Bean Chips       107
# 40          41  Organic Sourdough Einkorn Crackers Rosemary        78
#
#     department_id  prices
# 0              19     5.8
# 15             19     5.2
# 24             19     1.9
# 31             19     4.9
# 40             19     6.5

# %%
## Can do it like this too

## isin tells the loc function to look at a list - so could be more than one value there

df_snacks_3 = df_prods.loc[df_prods['department_id'].isin([19])]

# %%
df_snacks_3.head()
# Out:
#     product_id                                 product_name  aisle_id  \
# 0            1                   Chocolate Sandwich Cookies        61
# 15          16                Mint Chocolate Flavored Syrup       103
# 24          25      Salted Caramel Lean Protein & Fiber Bar         3
# 31          32                Nacho Cheese White Bean Chips       107
# 40          41  Organic Sourdough Einkorn Crackers Rosemary        78
#
#     department_id  prices
# 0              19     5.8
# 15             19     5.2
# 24             19     1.9
# 31             19     4.9
# 40             19     6.5

# %%
## More than one value

df_snacks_4 = df_prods.loc[df_prods['department_id'].isin([18,19])]

# %%
df_snacks_4.head()
# Out:
#     product_id                             product_name  aisle_id  \
# 0            1               Chocolate Sandwich Cookies        61
# 14          15                 Overnight Diapers Size 6        56
# 15          16            Mint Chocolate Flavored Syrup       103
# 24          25  Salted Caramel Lean Protein & Fiber Bar         3
# 31          32            Nacho Cheese White Bean Chips       107
#
#     department_id  prices
# 0              19     5.8
# 14             18    11.2
# 15             19     5.2
# 24             19     1.9
# 31             19     4.9

# %%
###Tis is the colab way to export data

df_ords.to_csv(os.path.join(r'/content/', 'orders_wrangled.csv'))

# %% [markdown]
# # **TASK**

# %%
## -- Loading Libraries --
import pandas as pd
import numpy as np
import os

# %%
df_ords = pd.read_csv(r'/content/orders.csv', index_col = False)
df_prods = pd.read_csv(r'/content/products.csv', index_col = False)
df_dep = pd.read_csv(r'/content/departments.csv', index_col = False)

# %%
#Quick look at ords

df_ords.head()
# Out:
#    order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1    prior             1          2                  8
# 1   2398795        1    prior             2          3                  7
# 2    473747        1    prior             3          3                 12
# 3   2254736        1    prior             4          4                  7
# 4    431534        1    prior             5          4                 15
#
#    days_since_prior_order
# 0                     NaN
# 1                    15.0
# 2                    21.0
# 3                    29.0
# 4                    28.0

# %% [markdown]
# Change data type

# %%
## Don't want to perform any calculations on User ID, it's just a descriptor - so change type to String

df_ords['user_id'] = df_ords['user_id'].astype('str')

# %%
##Checking what type it is

df_ords['user_id'].dtype
# Out:
# dtype('O')

# %% [markdown]
# Renaming columns

# %%
##renaming two columns

df_ords.rename(columns = {'order_dow' : 'order_day'}, inplace = True)
df_ords.rename(columns = {'order_hour_of_day' : 'order_hour'}, inplace = True)

# %%
df_ords.head()
# Out:
#    order_id user_id eval_set  order_number  order_day  order_hour  \
# 0   2539329       1    prior             1          2           8
# 1   2398795       1    prior             2          3           7
# 2    473747       1    prior             3          3          12
# 3   2254736       1    prior             4          4           7
# 4    431534       1    prior             5          4          15
#
#    days_since_prior_order
# 0                     NaN
# 1                    15.0
# 2                    21.0
# 3                    29.0
# 4                    28.0

# %% [markdown]
# Find count of all values in a column

# %%
##Finding the most frequent hour to order

#Answer = 10

df_ords['order_hour'].value_counts(dropna = False)
# Out:
# order_hour
# 10    14472
# 11    14395
# 15    14233
# 13    14206
# 14    14164
# 12    14087
# 16    13765
# 9     12904
# 17    11605
# 18     9382
# 8      8979
# 19     7146
# 20     5162
# 7      4610
# 21     3924
# 22     3119
# 23     1938
# 6      1596
# 0      1072
# 1       621
# 5       548
# 2       341
# 4       327
# 3       264
# Name: count, dtype: int64

# %% [markdown]
# Using a data dictionary

# %%
#Instruction: Determine the meaning behind a value of 4 in the "department_id" column within the df_prods dataframe using a data dictionary.

data_dict = df_dep.to_dict('index')

# %%
data_dict
# Out:
# {0: {'department_id': 'department',
#   '1': 'frozen',
#   '2': 'other',
#   '3': 'bakery',
#   '4': 'produce',
#   '5': 'alcohol',
#   '6': 'international',
#   '7': 'beverages',
#   '8': 'pets',
#   '9': 'dry goods pasta',
#   '10': 'bulk',
#   '11': 'personal care',
#   '12': 'meat seafood',
#   '13': 'pantry',
#   '14': 'breakfast',
#   '15': 'canned goods',
#   '16': 'dairy eggs',
#   '17': 'household',
#   '18': 'babies',
#   '19': 'snacks',
#   '20': 'deli',
#   '21': 'missing'}}

# %%
#value of 4 in the "department_id" column within the df_prods = 'Produce'

# %% [markdown]
# Creating a subset

# %%
#The sales team in your client’s organization wants to know more about breakfast item sales. Create a subset containing only the required information.

# Breakfast is department_id = 14

# %%
df_breakfast = df_prods[df_prods['department_id']==14]

# %%
df_breakfast.head()
# Out:
#      product_id                                      product_name  aisle_id  \
# 27           28                                 Wheat Chex Cereal       121
# 33           34                                               NaN       121
# 67           68                           Pancake Mix, Buttermilk       130
# 89           90                                      Smorz Cereal       121
# 210         211  Gluten Free Organic Cereal Coconut Maple Vanilla       130
#
#      department_id  prices
# 27              14    10.1
# 33              14    12.2
# 67              14    13.7
# 89              14     3.9
# 210             14     3.6

# %% [markdown]
# Subset of multiple items

# %%
#INSTRUCTION: They’d also like to see details about products that customers might use to throw dinner parties.
# Your task is to find all observations from the entire dataframe that include items from the following departments: alcohol, deli, beverages, and meat/seafood.
# You’ll need to present this subset to your client.

# %%
df_dinner_party = df_prods.loc[df_prods['department_id'].isin([5,7,12,20])]

# %%
df_dinner_party.head(20)
# Out:
#     product_id                                       product_name  aisle_id  \
# 2            3               Robust Golden Unsweetened Oolong Tea        94
# 6            7                     Pure Coconut Water With Orange        98
# 9           10     Sparkling Orange Juice & Prickly Pear Beverage       115
# 10          11                                  Peach Mango Juice        31
# 16          17                                  Rendered Duck Fat        35
# 19          20     Pomegranate Cranberry & Aloe Vera Enrich Drink        98
# 22          23                             Organic Turkey Burgers        49
# 34          35     Italian Herb Porcini Mushrooms Chicken Sausage       106
# 38          39           Daily Tangerine Citrus Flavored Beverage        64
# 39          40  Beef Hot Links Beef Smoked Sausage With Chile ...       106
# 43          44                        Sparkling Raspberry Seltzer       115
# ...

# %%
#It’s important that you keep track of total counts in your dataframes. How many rows does the last dataframe you created have?

#7,650 Rows

df_dinner_party.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3460624145.py in <cell line: 0>()
#       3 #7,650 Rows
#       4
# ----> 5 df_dinner_party.shape
#
# NameError: name 'df_dinner_party' is not defined

# %% [markdown]
# Find infomration relating to one value

# %%
#Instruction: Someone from the data engineers team in Instacart thinks they’ve spotted something strange about the customer with a "user_id" of “1.” Extract all the information you can about this user.

# %%
df_ords.head()
# Out:
#    order_id user_id eval_set  order_number  order_day  order_hour  \
# 0   2539329       1    prior             1          2           8
# 1   2398795       1    prior             2          3           7
# 2    473747       1    prior             3          3          12
# 3   2254736       1    prior             4          4           7
# 4    431534       1    prior             5          4          15
#
#    days_since_prior_order
# 0                     NaN
# 1                    15.0
# 2                    21.0
# 3                    29.0
# 4                    28.0

# %%
df_user_1 = df_ords[df_ords['user_id']=='1']

# %%
df_user_1.head(20)
# Out:
#     order_id user_id eval_set  order_number  order_day  order_hour  \
# 0    2539329       1    prior             1          2           8
# 1    2398795       1    prior             2          3           7
# 2     473747       1    prior             3          3          12
# 3    2254736       1    prior             4          4           7
# 4     431534       1    prior             5          4          15
# 5    3367565       1    prior             6          2           7
# 6     550135       1    prior             7          1           9
# 7    3108588       1    prior             8          1          14
# 8    2295261       1    prior             9          1          16
# 9    2550362       1    prior            10          4           8
# 10   1187899       1    train            11          4           8
#
#     days_since_prior_order
# 0                      NaN
# 1                     15.0
# 2                     21.0
# 3                     29.0
# ...

# %%
#INSTRUCTION: You also need to provide some details about this user’s behavior. What basic stats can you provide based on the information you have?

df_user_1.describe()
# Out:
#            order_id  order_number  order_day  order_hour  \
# count  1.100000e+01     11.000000  11.000000   11.000000
# mean   1.923450e+06      6.000000   2.636364   10.090909
# std    1.071950e+06      3.316625   1.286291    3.477198
# min    4.315340e+05      1.000000   1.000000    7.000000
# 25%    8.690170e+05      3.500000   1.500000    7.500000
# 50%    2.295261e+06      6.000000   3.000000    8.000000
# 75%    2.544846e+06      8.500000   4.000000   13.000000
# max    3.367565e+06     11.000000   4.000000   16.000000
#
#        days_since_prior_order
# count               10.000000
# mean                19.000000
# std                  9.030811
# min                  0.000000
# 25%                 14.250000
# 50%                 19.500000
# 75%                 26.250000
# max                 30.000000

# %%
#Export as csv

df_ords.to_csv(os.path.join(r'/content/', 'def_dep_t_new.csv'))
